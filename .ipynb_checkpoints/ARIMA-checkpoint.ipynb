# %% [markdown]
# ##### This notebook contains ΑΡΙΜΑ.
# ARIMA, short for 'Auto Regressive Integrated Moving Average' is actually a class of models that 'explains' a given time series based on its own past values, that is, its own lags and the lagged forecast errors, so that equation can be used to forecast future values.

# %% [markdown]
# ##### Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot  as plt
import seaborn as sns
import math
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error, mean_absolute_error

import warnings
warnings.filterwarnings("ignore")

from statsmodels.tsa.stattools import adfuller

# %% [markdown]
# ##### Dataset Loading

# %%
dataset = pd.read_csv("Data/BTC-USD.csv")
print(dataset.shape)
dataset.head()
# Out:
# (1827, 7)
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2016-12-21  800.643982  834.281006  799.405029  834.281006  834.281006
# 1  2016-12-22  834.179993  875.781982  834.148987  864.539978  864.539978
# 2  2016-12-23  864.888000  925.117004  864.677002  921.984009  921.984009
# 3  2016-12-24  922.179993  923.479004  886.335022  898.822021  898.822021
# 4  2016-12-25  899.651978  899.651978  862.424011  896.182983  896.182983
#
#       Volume
# 0  155576000
# 1  200027008
# 2  275564000
# 3  137727008
# 4  143664992

# %%
dataset["Date"]=pd.to_datetime(dataset['Date'])
dataset['Year'] = dataset['Date'].dt.year
dataset
# Out:
#            Date          Open          High           Low         Close  \
# 0    2016-12-21    800.643982    834.281006    799.405029    834.281006
# 1    2016-12-22    834.179993    875.781982    834.148987    864.539978
# 2    2016-12-23    864.888000    925.117004    864.677002    921.984009
# 3    2016-12-24    922.179993    923.479004    886.335022    898.822021
# 4    2016-12-25    899.651978    899.651978    862.424011    896.182983
# ...         ...           ...           ...           ...           ...
# 1822 2021-12-17  47653.730469  48004.894531  45618.214844  46202.144531
# 1823 2021-12-18  46219.253906  47313.828125  45598.441406  46848.777344
# 1824 2021-12-19  46853.867188  48089.664063  46502.953125  46707.015625
# 1825 2021-12-20  46707.062500  47401.718750  45579.808594  46880.277344
# 1826 2021-12-21  46985.242188  48912.152344  46739.777344  48565.843750
#
#          Adj Close       Volume  Year
# 0       834.281006    155576000  2016
# 1       864.539978    200027008  2016
# 2       921.984009    275564000  2016
# 3       898.822021    137727008  2016
# 4       896.182983    143664992  2016
# ...            ...          ...   ...
# 1822  46202.144531  32902725329  2021
# 1823  46848.777344  26098292690  2021
# 1824  46707.015625  25154053861  2021
# 1825  46880.277344  30961902129  2021
# 1826  48565.843750  30736644096  2021
#
# [1827 rows x 8 columns]

# %% [markdown]
# We only need the Closing values.

# %%
ts = dataset['Close'].copy()

# %%
ts.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# In order to create ARIMA, our dataset should be stationary. According to the previous plot, our dataset is non stationary so we are going to use some techniqs to make it stationary. We are going to use the Null Hypothesis. </br>
# According to it,only if p value > 0.05: Null Hypothesis is accepted. </br>
# H0: the data is not stationary.

# %%
def test_for_stationary(input_data):
    r_mean = input_data.rolling(window = 7,center=False).mean()
    r_std = input_data.rolling(window = 7,center=False).std()
    
    # plotting the data
    given = plt.plot(input_data, color = 'blue', label = 'given_series')
    rolling_mean = plt.plot(r_mean, color = 'red', label = 'rolling_mean')
    rolling_std = plt.plot(r_std, color ='green', label = 'rolling_std')
    plt.legend(loc = 'best')
    plt.title('Rolling Mean & Standard Deviation')
    plt.show(block=False)
    
     #Perform Dickey-Fuller test:
    print('Results of Dickey-Fuller Test:')
    dftest = adfuller(input_data)
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    print(dfoutput)
      
test_for_stationary(ts)

#Source: https://machinelearningmastery.com/time-series-data-stationary-python/
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                   -0.602678
# p-value                           0.870376
# #Lags Used                       24.000000
# Number of Observations Used    1802.000000
# Critical Value (1%)              -3.433984
# Critical Value (5%)              -2.863145
# Critical Value (10%)             -2.567625
# dtype: float64

# %% [markdown]
# According to the results, p-value > 0.05, so H0 is accepted and our dataset is not stationary. </br>
# The next step is to use log.

# %%
ts_log = np.log(ts)
plt.plot(ts_log)

# %%
test_for_stationary(ts_log)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                   -1.489247
# p-value                           0.538824
# #Lags Used                        2.000000
# Number of Observations Used    1824.000000
# Critical Value (1%)              -3.433940
# Critical Value (5%)              -2.863126
# Critical Value (10%)             -2.567614
# dtype: float64

# %% [markdown]
# According to the results, still p-value > 0.05, so H0 is accepted and our dataset is not stationary. </br>
# So we have to remove trend and seasonality with differencing.

# %%
ts_log_diff = ts_log -ts_log.shift()
plt.plot(ts_log_diff)

# %%
ts_log_diff.dropna(inplace=True)
test_for_stationary(ts_log_diff)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -29.709082
# p-value                           0.000000
# #Lags Used                        1.000000
# Number of Observations Used    1824.000000
# Critical Value (1%)              -3.433940
# Critical Value (5%)              -2.863126
# Critical Value (10%)             -2.567614
# dtype: float64

# %% [markdown]
# As our time series is now stationary asour p value is less than 0.05 therefore we can apply time series forecasting models.

# %%
ts_log_diff.describe()
# Out:
# count    1826.000000
# mean        0.002226
# std         0.042281
# min        -0.464730
# 25%        -0.015421
# 50%         0.002415
# 75%         0.021709
# max         0.225119
# Name: Close, dtype: float64

# %% [markdown]
# ### Split Data

# %%
to_row = int(len(ts_log_diff)*0.9)
training_data = list(ts_log_diff[0:to_row])
testing_data = list(ts_log_diff[to_row:])

# %%
plt.figure(figsize=(10,6))
plt.grid(True)
plt.xlabel("Date")
plt.ylabel("Closing Prices")
plt.plot(ts_log_diff[0:to_row],'green',label="Training data")
plt.plot(ts_log_diff[to_row:],'blue',label="Testing data")
plt.legend()

# %% [markdown]
# ### ARIMA

# %%
len(training_data)
# Out:
# 1643

# %%
len(testing_data)
# Out:
# 183

# %%
model_predictions=[]
error_list=[]
n_test_observ = len(testing_data)

# %%
for i in range (n_test_observ):
    model = ARIMA(training_data, order = (4, 1, 1))
    model_fit = model.fit()
    output = model_fit.forecast()
    yhat = output[0]
    model_predictions.append(yhat)
    actual_test_value = testing_data[i]
    training_data.append(actual_test_value)
    
    # Calculating the error
    error = ((abs(yhat - actual_test_value)) / actual_test_value) * 100
    
    error_list.append(error)
    print('predicted = %f,   expected = %f,   error = %f ' % (yhat, actual_test_value, error), '%')
    
    
    
# After iterating over whole test set the overall mean error is calculated.   
print('\n Mean Error in Predicting Test Case Articles : %f ' % (sum(error_list)/float(len(error_list))), '%')
# Out:
# predicted = 0.005454,   expected = 0.025833,   error = 78.886660  %
# predicted = -0.004972,   expected = 0.036767,   error = 113.523022  %
# predicted = 0.001276,   expected = 0.027476,   error = 95.356541  %
# predicted = 0.001793,   expected = -0.091305,   error = -101.963982  %
# predicted = 0.005794,   expected = 0.017188,   error = 66.288108  %
# predicted = -0.002935,   expected = 0.073747,   error = 103.980364  %
# predicted = -0.000102,   expected = -0.006233,   error = -98.365743  %
# predicted = 0.004212,   expected = 0.040785,   error = 89.673523  %
# predicted = 0.000197,   expected = -0.023325,   error = -100.846457  %
# predicted = 0.004776,   expected = -0.042818,   error = -111.155075  %
# predicted = 0.002181,   expected = 0.009632,   error = 77.357653  %
# predicted = -0.000338,   expected = 0.022505,   error = 101.501370  %
# predicted = 0.001136,   expected = 0.017704,   error = 93.580988  %
# predicted = 0.001662,   expected = -0.044675,   error = -103.720183  %
# predicted = 0.003990,   expected = 0.014392,   error = 72.278136  %
# predicted = -0.001006,   expected = -0.011158,   error = -90.980030  %
# predicted = 0.002651,   expected = -0.029312,   error = -109.042616  %
# predicted = 0.001685,   expected = 0.027617,   error = 93.897281  %
# predicted = -0.000605,   expected = -0.008244,   error = -92.656574  %
# predicted = 0.002807,   expected = 0.021242,   error = 86.788010  %
# predicted = 0.000303,   expected = -0.032181,   error = -100.942357  %
# predicted = 0.003642,   expected = -0.013782,   error = -126.424062  %
# predicted = 0.000451,   expected = 0.003673,   error = 87.714930  %
# predicted = 0.000760,   expected = -0.032249,   error = -102.357355  %
# predicted = 0.002266,   expected = -0.011367,   error = -119.935833  %
# predicted = 0.000009,   expected = 0.003543,   error = 99.733441  %
# predicted = -0.000405,   expected = 0.008329,   error = 104.865365  %
# predicted = 0.000686,   expected = -0.031273,   error = -102.195111  %
# predicted = 0.002249,   expected = -0.033339,   error = -106.746184  %
# predicted = 0.000537,   expected = 0.074434,   error = 99.279148  %
# predicted = -0.003061,   expected = 0.006284,   error = 148.711174  %
# predicted = 0.003587,   expected = 0.038504,   error = 90.684485  %
# predicted = -0.000027,   expected = 0.020948,   error = 100.127988  %
# predicted = 0.002199,   expected = 0.030379,   error = 92.762819  %
# predicted = 0.000897,   expected = 0.054695,   error = 98.360298  %
# predicted = 0.000410,   expected = 0.053943,   error = 99.239512  %
# predicted = 0.002711,   expected = 0.014835,   error = 81.726525  %
# predicted = 0.004340,   expected = 0.000313,   error = 1286.997722  %
# predicted = 0.003331,   expected = 0.054172,   error = 93.850483  %
# predicted = 0.001017,   expected = -0.014533,   error = -107.001283  %
# predicted = 0.005112,   expected = -0.040478,   error = -112.628460  %
# predicted = 0.002948,   expected = -0.019525,   error = -115.098793  %
# predicted = 0.001361,   expected = -0.027122,   error = -105.016218  %
# predicted = 0.001934,   expected = 0.040943,   error = 95.277009  %
# predicted = -0.000831,   expected = 0.027838,   error = 102.986569  %
# predicted = 0.002598,   expected = 0.046538,   error = 94.416681  %
# predicted = 0.001843,   expected = 0.039819,   error = 95.370368  %
# predicted = 0.003462,   expected = -0.017152,   error = -120.183718  %
# predicted = 0.004866,   expected = 0.056963,   error = 91.456942  %
# predicted = 0.000691,   expected = -0.016974,   error = -104.070005  %
# predicted = 0.005825,   expected = 0.000189,   error = 2986.102157  %
# predicted = 0.002132,   expected = -0.025892,   error = -108.233181  %
# predicted = 0.003716,   expected = 0.073009,   error = 94.910506  %
# predicted = -0.001398,   expected = -0.014678,   error = -90.476669  %
# predicted = 0.006307,   expected = -0.001061,   error = -694.482113  %
# predicted = 0.001919,   expected = -0.022408,   error = -108.563591  %
# predicted = 0.003563,   expected = -0.028869,   error = -112.340892  %
# predicted = 0.001526,   expected = 0.002365,   error = 35.481829  %
# predicted = 0.001041,   expected = 0.041886,   error = 97.514763  %
# predicted = 0.000964,   expected = 0.054598,   error = 98.233691  %
# predicted = 0.002586,   expected = -0.008829,   error = -129.293561  %
# predicted = 0.005587,   expected = 0.008473,   error = 34.065207  %
# predicted = 0.002427,   expected = 0.004541,   error = 46.566818  %
# predicted = 0.003136,   expected = -0.037845,   error = -108.285999  %
# predicted = 0.004002,   expected = 0.025960,   error = 84.585145  %
# predicted = 0.000195,   expected = -0.042102,   error = -100.462554  %
# predicted = 0.005082,   expected = 0.044099,   error = 88.476799  %
# predicted = -0.000974,   expected = -0.003190,   error = -69.471562  %
# predicted = 0.004805,   expected = -0.001485,   error = -423.543351  %
# predicted = 0.002289,   expected = -0.037025,   error = -106.181961  %
# predicted = 0.004047,   expected = 0.002371,   error = 70.668295  %
# predicted = 0.000773,   expected = 0.035006,   error = 97.792549  %
# predicted = 0.001426,   expected = 0.009793,   error = 85.442006  %
# predicted = 0.003468,   expected = 0.014044,   error = 75.304588  %
# predicted = 0.002477,   expected = -0.001615,   error = -253.325418  %
# predicted = 0.003541,   expected = 0.035575,   error = 90.045107  %
# predicted = 0.001462,   expected = 0.016863,   error = 91.331409  %
# predicted = 0.003869,   expected = -0.117232,   error = -103.299895  %
# predicted = 0.006982,   expected = -0.015495,   error = -145.061471  %
# predicted = -0.001674,   expected = 0.006488,   error = 125.805926  %
# predicted = -0.000193,   expected = -0.033035,   error = -99.416595  %
# predicted = 0.003281,   expected = 0.007050,   error = 53.454135  %
# predicted = 0.000515,   expected = 0.018887,   error = 97.272020  %
# predicted = 0.001927,   expected = -0.024174,   error = -107.970100  %
# predicted = 0.003663,   expected = 0.046272,   error = 92.083215  %
# predicted = -0.000238,   expected = 0.022755,   error = 101.046389  %
# predicted = 0.003617,   expected = -0.008191,   error = -144.161592  %
# predicted = 0.003555,   expected = -0.010854,   error = -132.750753  %
# predicted = 0.002727,   expected = 0.021160,   error = 87.111656  %
# predicted = 0.001485,   expected = -0.021315,   error = -106.966046  %
# predicted = 0.003903,   expected = -0.098108,   error = -103.978213  %
# predicted = 0.004625,   expected = -0.051488,   error = -108.983486  %
# predicted = -0.000389,   expected = 0.068400,   error = 100.568453  %
# predicted = -0.002843,   expected = 0.029856,   error = 109.521810  %
# predicted = 0.003053,   expected = -0.046862,   error = -106.514324  %
# predicted = 0.004345,   expected = -0.002879,   error = -250.934455  %
# predicted = 0.000978,   expected = 0.011451,   error = 91.461994  %
# predicted = 0.001731,   expected = -0.022772,   error = -107.602520  %
# predicted = 0.002717,   expected = -0.028852,   error = -109.416935  %
# predicted = 0.001986,   expected = 0.012829,   error = 84.517674  %
# predicted = 0.000457,   expected = 0.052183,   error = 99.123578  %
# predicted = 0.000475,   expected = 0.094208,   error = 99.495793  %
# predicted = 0.000959,   expected = -0.008462,   error = -111.338521  %
# predicted = 0.006309,   expected = 0.010186,   error = 38.063410  %
# predicted = 0.002108,   expected = 0.018764,   error = 88.763567  %
# predicted = 0.002943,   expected = 0.047748,   error = 93.836621  %
# predicted = 0.001594,   expected = 0.072014,   error = 97.787118  %
# predicted = 0.001935,   expected = -0.028499,   error = -106.789562  %
# predicted = 0.006398,   expected = 0.003004,   error = 113.004417  %
# predicted = 0.002231,   expected = 0.018367,   error = 87.855266  %
# predicted = 0.002832,   expected = -0.003584,   error = -179.009603  %
# predicted = 0.003184,   expected = 0.048349,   error = 93.415017  %
# predicted = 0.001161,   expected = -0.025436,   error = -104.564868  %
# predicted = 0.005266,   expected = 0.023979,   error = 78.037649  %
# predicted = 0.001102,   expected = -0.001387,   error = -179.451547  %
# predicted = 0.004138,   expected = 0.071887,   error = 94.244150  %
# predicted = 0.000356,   expected = -0.011459,   error = -103.104645  %
# predicted = 0.006229,   expected = 0.010804,   error = 42.342664  %
# predicted = 0.002130,   expected = 0.007646,   error = 72.137261  %
# predicted = 0.003960,   expected = 0.035413,   error = 88.816598  %
# predicted = 0.002775,   expected = 0.026578,   error = 89.557719  %
# predicted = 0.003830,   expected = -0.059028,   error = -106.488267  %
# predicted = 0.005953,   expected = -0.024702,   error = -124.098145  %
# predicted = 0.001989,   expected = 0.011490,   error = 82.689541  %
# predicted = 0.002106,   expected = -0.007566,   error = -127.837473  %
# predicted = 0.002904,   expected = 0.034027,   error = 91.466831  %
# predicted = 0.001245,   expected = -0.043377,   error = -102.869996  %
# predicted = 0.005928,   expected = -0.031664,   error = -118.722074  %
# predicted = 0.002738,   expected = 0.035934,   error = 92.379973  %
# predicted = 0.000784,   expected = 0.026144,   error = 97.001428  %
# predicted = 0.002891,   expected = -0.005465,   error = -152.899059  %
# predicted = 0.003629,   expected = -0.009251,   error = -139.234563  %
# predicted = 0.003122,   expected = -0.005143,   error = -160.709020  %
# predicted = 0.002941,   expected = 0.035776,   error = 91.779101  %
# predicted = 0.001569,   expected = -0.004063,   error = -138.617701  %
# predicted = 0.004798,   expected = -0.024399,   error = -119.665409  %
# predicted = 0.003618,   expected = -0.005328,   error = -167.895144  %
# predicted = 0.002742,   expected = 0.006552,   error = 58.154154  %
# predicted = 0.002402,   expected = 0.028828,   error = 91.669089  %
# predicted = 0.003002,   expected = 0.064806,   error = 95.367899  %
# predicted = 0.001872,   expected = -0.008845,   error = -121.164708  %
# predicted = 0.005900,   expected = -0.029958,   error = -119.693668  %
# predicted = 0.004222,   expected = -0.000697,   error = -705.901896  %
# predicted = 0.002542,   expected = -0.012300,   error = -120.665237  %
# predicted = 0.003162,   expected = 0.004876,   error = 35.156902  %
# predicted = 0.001938,   expected = 0.015351,   error = 87.373081  %
# predicted = 0.003321,   expected = -0.029593,   error = -111.220898  %
# predicted = 0.004219,   expected = -0.054922,   error = -107.682425  %
# predicted = 0.003315,   expected = 0.003431,   error = 3.387790  %
# predicted = 0.001494,   expected = -0.058424,   error = -102.557489  %
# predicted = 0.004023,   expected = 0.020467,   error = 80.345133  %
# predicted = -0.000950,   expected = 0.026782,   error = 103.546422  %
# predicted = 0.002629,   expected = -0.016326,   error = -116.099941  %
# predicted = 0.003514,   expected = -0.042455,   error = -108.276625  %
# predicted = 0.003384,   expected = 0.022481,   error = 84.948660  %
# predicted = 0.000528,   expected = -0.022639,   error = -102.330967  %
# predicted = 0.002048,   expected = 0.017512,   error = 88.302294  %
# predicted = 0.000524,   expected = -0.066874,   error = -100.783753  %
# predicted = 0.005276,   expected = 0.022980,   error = 77.040561  %
# predicted = -0.001197,   expected = 0.043435,   error = 102.756058  %
# predicted = 0.002056,   expected = 0.009702,   error = 78.809403  %
# predicted = 0.002788,   expected = -0.013956,   error = -119.978896  %
# predicted = 0.002988,   expected = 0.003929,   error = 23.943038  %
# predicted = 0.002115,   expected = -0.013227,   error = -115.988774  %
# predicted = 0.003002,   expected = -0.052332,   error = -105.736324  %
# predicted = 0.003318,   expected = -0.085608,   error = -103.875689  %
# predicted = 0.002810,   expected = 0.003412,   error = 17.639020  %
# predicted = -0.002814,   expected = 0.024289,   error = 111.585407  %
# predicted = 0.000775,   expected = 0.002319,   error = 66.568318  %
# predicted = 0.000776,   expected = -0.003859,   error = -120.113675  %
# predicted = 0.002149,   expected = -0.057722,   error = -103.723645  %
# predicted = 0.003662,   expected = -0.009036,   error = -140.531412  %
# predicted = -0.000109,   expected = 0.043880,   error = 100.249270  %
# predicted = -0.000252,   expected = 0.014797,   error = 101.701618  %
# predicted = 0.001788,   expected = -0.069441,   error = -102.574387  %
# predicted = 0.004096,   expected = -0.002675,   error = -253.117796  %
# predicted = 0.000117,   expected = 0.047839,   error = 99.756421  %
# predicted = -0.000157,   expected = -0.025504,   error = -99.384731  %
# predicted = 0.002825,   expected = -0.031180,   error = -109.060434  %
# predicted = 0.002286,   expected = 0.013899,   error = 83.555405  %
# predicted = 0.000529,   expected = -0.003031,   error = -117.444704  %
# predicted = 0.000568,   expected = 0.003703,   error = 84.646263  %
# predicted = 0.000497,   expected = 0.035323,   error = 98.593891  %
#
#  Mean Error in Predicting Test Case Articles : 5.184044  %

# %%
yhat
# Out:
# 0.0004966857168888818

# %%
print(model_fit.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 1825
# Model:                 ARIMA(4, 1, 1)   Log Likelihood                3179.902
# Date:                Thu, 06 Jan 2022   AIC                          -6347.804
# Time:                        02:21:52   BIC                          -6314.751
# Sample:                             0   HQIC                         -6335.611
#                                - 1825
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.0345      0.017     -2.039      0.041      -0.068      -0.001
# ar.L2          0.0330      0.020      1.617      0.106      -0.007       0.073
# ar.L3         -0.0026      0.021     -0.124      0.901      -0.044       0.039
# ar.L4          0.0143      0.019      0.759      0.448      -0.023       0.051
# ma.L1         -0.9954      0.003   -365.772      0.000      -1.001      -0.990
# sigma2         0.0018   2.58e-05     69.562      0.000       0.002       0.002
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):              8459.21
# Prob(Q):                              0.96   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.60   Skew:                            -0.80
# Prob(H) (two-sided):                  0.00   Kurtosis:                        13.43
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
len(model_predictions)
# Out:
# 183

# %%
len(testing_data)
# Out:
# 183

# %%
len(ts_log_diff)
# Out:
# 1826

# %%
plt.figure(figsize=(15,9))
plt.grid(True)

data_range = ts_log_diff[to_row:].index

#plt.plot(ts_log_diff)
plt.plot(data_range,model_predictions,color = 'red', linestyle = 'dashed',label='Predicted Close')
plt.plot(data_range,testing_data,color = 'blue',label='Close')

'''plt.plot(data_range,model_predictions,color = 'red', linestyle = 'dashed',label='Predicted Close')
plt.plot(data_range,testing_data,color = 'blue',label='Close')

plt.xlabel('Date')
plt.ylabel('Close')
plt.legend()
plt.show()'''
# Out:
# "plt.plot(data_range,model_predictions,color = 'red', linestyle = 'dashed',label='Predicted Close')\nplt.plot(data_range,testing_data,color = 'blue',label='Close')\n\nplt.xlabel('Date')\nplt.ylabel('Close')\nplt.legend()\nplt.show()"

# %%
plt.figure(figsize=(15,9))
to_row = int(len(ts_log)*0.9)
plt.grid(True)

data_range = ts_log[to_row:].index

plt.plot(data_range,model_predictions,color = 'red', linestyle = 'dashed',label='Predicted')
plt.plot(data_range,testing_data,color = 'blue',label='Expected')

plt.xlabel('Date')
plt.ylabel('Close')
plt.legend()
plt.show()

# %%
model_predictions=[]
len(model_predictions)

# %%
for i in range (n_test_observ):
    model2 = ARIMA(training_data,order=(4,1,2))
    model_fit = model2.fit()
    output = model_fit.forecast()
    yhat2 = output[0]
    model_predictions.append(yhat2)
    actual_test_value2 = testing_data[i]
    training_data.append(actual_test_value2)
    
    # Calculating the error
    error2 = ((abs(yhat2 - actual_test_value2)) / actual_test_value2) * 100
    
    error_list.append(error2)
    print('predicted = %f,   expected = %f,   error = %f ' % (yhat2, actual_test_value2, error2), '%')
    
    
    
# After iterating over whole test set the overall mean error is calculated.   
print('\n Mean Error in Predicting Test Case Articles : %f ' % (sum(error_list)/float(len(error_list))), '%')

# %%
yhat2

# %%
print(model_fit.summary())

# %%
len(model_predictions)

# %%
len(testing_data)

# %%
len(training_data)

# %%
plt.figure(figsize=(15,9))
plt.grid(True)

data_range = ts_log_diff[to_row:].index

plt.plot(data_range,model_predictions,color = 'red', linestyle = 'dashed',label='Predicted Close')
plt.plot(data_range,testing_data,color = 'blue',label='Close')


plt.legend()
plt.show()

# %%
plt.figure(figsize=(15,9))
plt.grid(True)

data_range = ts_log[to_row:].index

plt.plot(data_range,model_predictions,color = 'red', linestyle = 'dashed',label='Predicted Close')
plt.plot(data_range,testing_data,color = 'blue',label='Close')

plt.xlabel('Date')
plt.ylabel('Close')
plt.legend()
plt.show()
